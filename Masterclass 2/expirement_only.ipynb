# %%
import pandas as pd

# %%
df = pd.read_csv("https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/sample_csv.csv")

# %%
df
# Out:
#      order_id  order_date  customer_id             city          province  \
# 0     1612339  2019-01-01        18055  Jakarta Selatan       DKI Jakarta
# 1     1612339  2019-01-01        18055  Jakarta Selatan       DKI Jakarta
# 2     1612339  2019-01-01        18055  Jakarta Selatan       DKI Jakarta
# 3     1612339  2019-01-01        18055  Jakarta Selatan       DKI Jakarta
# 4     1612339  2019-01-01        18055  Jakarta Selatan       DKI Jakarta
# ..        ...         ...          ...              ...               ...
# 96    1612390  2019-01-01        12681         Makassar  Sulawesi Selatan
# 97    1612390  2019-01-01        12681         Makassar  Sulawesi Selatan
# 98    1612390  2019-01-01        12681         Makassar  Sulawesi Selatan
# 99    1612390  2019-01-01        12681         Makassar  Sulawesi Selatan
# 100   1612390  2019-01-01        12681         Makassar  Sulawesi Selatan
#
#     product_id    brand  quantity  item_price
# ...

# %%
df = df.set_index(["order_date", "order_id", "product_id"])

# %%
df
# Out:
#                                 customer_id             city  \
# order_date order_id product_id
# 2019-01-01 1612339  P0648             18055  Jakarta Selatan
#                     P3826             18055  Jakarta Selatan
#                     P1508             18055  Jakarta Selatan
#                     P0520             18055  Jakarta Selatan
#                     P1513             18055  Jakarta Selatan
# ...                                     ...              ...
#            1612390  P3388             12681         Makassar
#                     P3082             12681         Makassar
#                     P3354             12681         Makassar
#                     P3357             12681         Makassar
#                     P0422             12681         Makassar
#
#                                         province    brand  quantity  \
# order_date order_id product_id
# 2019-01-01 1612339  P0648            DKI Jakarta  BRAND_C         4
# ...

# %%
df_slice = df.loc[("2019-01-01", 1612339, ["P2154", "P2159"]),:]
print("Slice df:\n", df_slice)
# Out:
# Slice df:
#                                  customer_id             city     province  \
# order_date order_id product_id
# 2019-01-01 1612339  P2154             18055  Jakarta Selatan  DKI Jakarta
#                     P2159             18055  Jakarta Selatan  DKI Jakarta
#
#                                   brand  quantity  item_price
# order_date order_id product_id
# 2019-01-01 1612339  P2154       BRAND_M         4     1745000
#                     P2159       BRAND_M        24      310000

# %%
dataku = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/LO4/global_air_quality_4000rows.csv')

# %%
dataku
# Out:
#                                     location                     city country  \
# 0                            MOBILE-KICKAPOO                  LINCOLN      US
# 1                            Oxford St Ebbes                   Oxford      GB
# 2                           BROADWAY (South)                St. Louis      US
# 3            Deen Dayal Nagar, Sagar - MPPCB                    Sagar      IN
# 4                                  Manglerud                     Oslo      NO
# ...                                      ...                      ...     ...
# 3995                              SPRINGHILL                Knoxville      US
# 3996                         Central Phoenix  Phoenix-Mesa-Scottsdale      US
# 3997                        Mobile-Wyandotte                   OTTAWA      US
# 3998  New Industrial Town, Faridabad - HSPCB                Faridabad      IN
# 3999                                    Reja                    Płock      PL
#
# ...

# %%
dataku[['country','city','pollutant','value']]
# Out:
#      country                     city pollutant     value
# 0         US                  LINCOLN      pm10     7.000
# 1         GB                   Oxford       no2    30.000
# 2         US                St. Louis      pm25     6.100
# 3         IN                    Sagar      pm25    23.670
# 4         NO                     Oslo      pm10    27.060
# ...      ...                      ...       ...       ...
# 3995      US                Knoxville        o3     0.046
# 3996      US  Phoenix-Mesa-Scottsdale        co     0.400
# 3997      US                   OTTAWA      pm10     6.000
# 3998      IN                Faridabad        co  1310.000
# 3999      PL                    Płock      pm10   134.000
#
# [4000 rows x 4 columns]

# %%
dataku2 = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/LO4/global_air_quality_4000rows.csv')

# %%
dataku2
# Out:
#                                     location                     city country  \
# 0                            MOBILE-KICKAPOO                  LINCOLN      US
# 1                            Oxford St Ebbes                   Oxford      GB
# 2                           BROADWAY (South)                St. Louis      US
# 3            Deen Dayal Nagar, Sagar - MPPCB                    Sagar      IN
# 4                                  Manglerud                     Oslo      NO
# ...                                      ...                      ...     ...
# 3995                              SPRINGHILL                Knoxville      US
# 3996                         Central Phoenix  Phoenix-Mesa-Scottsdale      US
# 3997                        Mobile-Wyandotte                   OTTAWA      US
# 3998  New Industrial Town, Faridabad - HSPCB                Faridabad      IN
# 3999                                    Reja                    Płock      PL
#
# ...
