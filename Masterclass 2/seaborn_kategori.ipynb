# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.describe(include='O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
# barplot (histogram)
sns.barplot(x = 'sex', y = 'fare', data=dataku);

# %%
sns.barplot(x = 'fare', y = 'sex', data=dataku);

# %%
sns.barplot(x = 'sex', y = 'fare', data=dataku, estimator = sum);

# %%
sns.barplot(x = 'sex', y = 'fare', data=dataku, estimator = np.std);

# %%
# Count plot
sns.countplot(x='sex', data=dataku);

# %%
sns.countplot(x='deck', hue='sex', data=dataku);

# %%
sns.countplot(x='deck', hue='sex', data=dataku, order = ['A','B','C','D','F','G']);

# %%
# Boxplot (box & whisker plot)
sns.boxplot(x = 'sex', y= 'fare', data=dataku);

# %%
sns.boxplot(x = 'sex', y= 'fare',hue = 'deck', data=dataku, hue_order=['A','B','C','D','E','F','G']);

# %%
sns.boxplot(x = 'sex', y= 'fare', data=dataku);

# %%
# Violin Plot
sns.violinplot(x='sex', y ='fare', data = dataku);

# %%
sns.violinplot(x = 'sex', y= 'fare',hue = 'deck', data=dataku, hue_order=['A','B','C','D','E','F','G']);

# %%
sns.boxplot(x = 'sex', y= 'fare',hue = 'deck', data=dataku, hue_order=['A','B','C','D','E','F','G']);

# %%
sns.violinplot(x='deck', y='fare', data= dataku, hue = 'sex',order=['A','B','C','D','E','F','G'], split=True);

# %%
# stripplot
sns.stripplot(x='deck', y='fare',hue='sex', order=['A','B','C','D','E','F','G'], data= dataku, jitter=True);

# %%
# swarmplot
sns.swarmplot(x='deck', y='fare',hue='sex', order=['A','B','C','D','E','F','G'], data= dataku);
# Out:
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x='deck', y='fare', order=['A','B','C','D','E','F','G'], data= dataku);
sns.swarmplot(x='deck', y='fare', order=['A','B','C','D','E','F','G'],color='black', data= dataku);
# Out:
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 22.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
